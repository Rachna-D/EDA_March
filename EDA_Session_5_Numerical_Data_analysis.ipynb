# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r'D:\Rachna\practice\Datafiles\Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **Select the numerical columns**

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **prevailing_wage**
# - len
# - max
# - min
# - mean
# - median
# - std
# - 75%
# - 50%
# - 25%

# %% [markdown]
# **count or len**

# %%
len(visa_df['prevailing_wage'])
# Out:
# 25480

# %% [markdown]
# **max**

# %%
max(visa_df['prevailing_wage'])  ## python keyword
# Out:
# 319210.27

# %%
visa_df['prevailing_wage'].max()     ## pandas
# Out:
# 319210.27

# %%
np.max(visa_df['prevailing_wage']) #### numpy
# Out:
# 319210.27

# %% [markdown]
# **min**

# %%
min(visa_df['prevailing_wage'])
# Out:
# 2.1367

# %%
np.min(visa_df['prevailing_wage'])
# Out:
# 2.1367

# %%
visa_df['prevailing_wage'].min()
# Out:
# 2.1367

# %% [markdown]
# **mean**

# %%
visa_df['prevailing_wage'].mean()
# Out:
# 74455.81459209183

# %%
np.mean(visa_df['prevailing_wage'])
# Out:
# 74455.81459209183

# %% [markdown]
# **median**

# %%
visa_df['prevailing_wage'].median()
# Out:
# 70308.20999999999

# %%
np.median(visa_df['prevailing_wage'])
# Out:
# 70308.20999999999

# %% [markdown]
# **standard deviation -- std**

# %%
np.std(visa_df['prevailing_wage'])
# Out:
# 52814.90589711402

# %%
visa_df['prevailing_wage'].std()
# Out:
# 52815.94232687357

# %% [markdown]
# **Mode is not a good option, because it is numerical variable**

# %%
#### Altogether

list_values=[]
wage_count=len(visa_df['prevailing_wage'])
wage_mean=visa_df['prevailing_wage'].mean()
wage_median=visa_df['prevailing_wage'].median()
wage_max=visa_df['prevailing_wage'].max()
wage_min=visa_df['prevailing_wage'].min()
wage_std=visa_df['prevailing_wage'].std()

### Create a dataframe

list_values=[wage_count,wage_mean,wage_median,wage_max,wage_min,wage_std]

index_val=['count','mean','median','max','min','std']

visa_df=pd.DataFrame(list_values,
                     columns=['prevailing_wage'],
                    index=index_val)

visa_df
# Out:
#         prevailing_wage
# count      25480.000000
# mean       74455.814592
# median     70308.210000
# max       319210.270000
# min            2.136700
# std        52815.942327

# %%
list_values=[]
wage_count=round(len(visa_df['prevailing_wage']),2)
wage_mean=round(visa_df['prevailing_wage'].mean(),2)
wage_median=round(visa_df['prevailing_wage'].median(),2)
wage_max=round(visa_df['prevailing_wage'].max(),2)
wage_min=round(visa_df['prevailing_wage'].min(),2)
wage_std=round(visa_df['prevailing_wage'].std(),2)

### Create a dataframe

list_values=[wage_count,wage_mean,wage_median,wage_max,wage_min,wage_std]

index_val=['count','mean','median','max','min','std']

visa_df=pd.DataFrame(list_values,
                     columns=['prevailing_wage'],
                    index=index_val)

visa_df

# %% [markdown]
# **percentile and quantile**
#
# - percentile
#     - np.percentile()
#     - it takes two arguments
#         - data : a
#         - percentile : q -- the values vary from 0 to 100
#         - if you want 50p data then q=50
#
# - quantile
#     - np.quantile()
#     - it takes two arguments
#         - data : a
#         - percentile : q -- the values vary from 0 to 100
#         - if you want 50p data then q=0.5

# %% [markdown]
# **25p-50p-75p**

# %%
wage_25p=round(np.percentile(visa_df['prevailing_wage'],25),2)
wage_50p=round(np.percentile(visa_df['prevailing_wage'],50),2)
wage_75p=round(np.percentile(visa_df['prevailing_wage'],75),2)

print(f'25% data is {wage_25p}')
print(f'50% data is {wage_50p}')
print(f'75% data is {wage_75p}')

## wrong values

# %%
wage_25p=round(np.quantile(visa_df['prevailing_wage'],0.25),2)
wage_50p=round(np.quantile(visa_df['prevailing_wage'],0.50),2)
wage_75p=round(np.quantile(visa_df['prevailing_wage'],0.75),2)

print(f'25% data is {wage_25p}')
print(f'50% data is {wage_50p}')
print(f'75% data is {wage_75p}')

## wrong values

# %% [markdown]
# **Understand the percentiles**
#
# - definition of 25 p
#     - there are 25% of employees has salary less than 34015
#     - total employees = 25480
#     - 25% empl = 25*25480/100 = 6370
#     - 6370 empl salary < 34015

# %%
con = visa_df['prevailing_wage']<34015
len(visa_df[con])

# %%
con = visa_df['prevailing_wage']<wage_25p
len(visa_df[con])

# %%
con = visa_df['prevailing_wage']<wage_50p
len(visa_df[con])

# %%
con = visa_df['prevailing_wage']<wage_75p
len(visa_df[con])

# %% [markdown]
# **Empirical rule (68-95-99.7)**
#
# ![image.png](attachment:41873ed4-5351-4438-9668-814c53990a72.png)

# %% [markdown]
# - first calculate mean value
# - second calculate std value
# - con1: mean-1*std
# - con2: mean-2*std
# - if you apply above conditions on wage data, output count should be equal to 68 percentile data
# - 68 % total employee: 17326

# %%
v1=wage_mean-1*wage_std
v2=wage_mean+1*wage_std
v1,v2

con1=visa_df['prevailing_wage']>v1
con2=visa_df['prevailing_wage']<v2

count1=visa_df[con1 & con2]
count1

# %%
v1=wage_mean-1*wage_std
v2=wage_mean+1*wage_std
v1,v2

con1=visa_df['prevailing_wage']>v1
con2=visa_df['prevailing_wage']<v2

count1=len(visa_df[con1 & con2])
########################################################
wage_68p=np.percentile(visa_df['prevailing_wage'],68)

count1, 68*25480/100

# %%
v1=wage_mean-2*wage_std
v2=wage_mean+2*wage_std
v1,v2

con1=visa_df['prevailing_wage']>v1
con2=visa_df['prevailing_wage']<v2

count1=visa_df[con1 & con2]
########################################################
wage_68p=np.percentile(visa_df['prevailing_wage'],68)

count1, 95*25480/100

# %%
v1=wage_mean-3*wage_std
v2=wage_mean+3*wage_std
v1,v2

con1=visa_df['prevailing_wage']>v1
con2=visa_df['prevailing_wage']<v2

count1=visa_df[con1 & con2]
########################################################
wage_68p=np.percentile(visa_df['prevailing_wage'],68)

count1, 99.7*25480/100

# %% [markdown]
# **Number of employees**

# %%
list_values=[]
wage_count=len(visa_df['no_of_employees'])
wage_mean=visa_df['no_of_employees'].mean()
wage_median=visa_df['no_of_employees'].median()
wage_max=visa_df['no_of_employees'].max()
wage_min=visa_df['no_of_employees'].min()
wage_std=visa_df['no_of_employees'].std()

###################################################################

wage_25p=round(np.quantile(visa_df['no_of_employees'],0.25),2)
wage_50p=round(np.quantile(visa_df['no_of_employees'],0.50),2)
wage_75p=round(np.quantile(visa_df['no_of_employees'],0.75),2)

###################################################################

list_values=[wage_count,wage_mean,wage_median,wage_max,wage_min,wage_std,
            wage_25p,wage_50p,wage_75p]

index_val=['count','mean','median','max','min','std',
          '25%','50%','75%']

visa_df=pd.DataFrame(list_values,
                     columns=['no_of_employees'],
                    index=index_val)

visa_df

# %%
num = visa_df.select_dtypes(exclude='object').columns

for i in num:
    wage_count=len(visa_df[i])
    wage_mean=visa_df[i].mean()
    print(wage_count,wage_mean)

# %%
## All together

l1=[]
cols=['no_of_employees','yr_of_estab','prevailing_wage']

##also cols=visa_df.select_dtypes(exclude='object').columns

for i in cols:
    countt=round(len(visa_df[i]),2)
    mean=round(visa_df[i].mean(),2)
    median=round(visa_df[i].median(),2)
    maxx=round(visa_df[i].max(),2)
    minx=round(visa_df[i].min(),2)
    std=round(visa_df[i].std(),2)
    
    ###################################################################
    
    p_25=round(np.quantile(visa_df[i],0.25),2)
    p_50=round(np.quantile(visa_df[i],0.50),2)
    p_75=round(np.quantile(visa_df[i],0.75),2)
    
    ###################################################################
    
    l1.append([countt,mean,median,maxx,minx,std,p_25,p_50,p_75])

l1

index_val=['count','mean','median','maxx','minx','std','p_25','p_50','p_75']
df=pd.DataFrame(l1,
               columns=index_val,
               index=cols).T

df
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00         25480.00
# mean            5667.04      1979.41         74455.81
# median          2109.00      1997.00         70308.21
# maxx          602069.00      2016.00        319210.27
# minx             -26.00      1800.00             2.14
# std            22877.93        42.37         52815.94
# p_25            1022.00      1976.00         34015.48
# p_50            2109.00      1997.00         70308.21
# p_75            3504.00      2005.00        107735.51

# %%
### till now we did it using the python skills

# %% [markdown]
# **describe**

# %%
visa_df.describe()

## describe() -- is it for only numerical data

# %% [markdown]
# **Histogram**
#
# - Histogram can get by matplotlib
# - Histogram can get by seaborn as well
# - plt.hist()

# %%
plt.hist(visa_df['prevailing_wage'])
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# *from interval range*
#
#     - 2.13670000e+00 to 3.19229500e+04
#     - 6038 members have salary
#     - 3.19229500e+04 to 6.38437634e+04
#     - 5504 members have salary
#     - 6.38437634e+04 to 9.57645767e+04
#     - 5681  .... etc
#
# *Histogram will give 3 outputs*
#
# *frequency*
#
#   - in each interval range how many observations are there
#   - interval
#   - number of intervals

# %% [markdown]
# **Check point-1**

# %%
2.13670000e+00, 3.19229500e+04
# Out:
# (2.1367, 31922.95)

# %%
con1=visa_df['prevailing_wage']>2.1367
con2=visa_df['prevailing_wage']<31922.95

len(visa_df[con1&con2])
# Out:
# 6037

# %%
import matplotlib.pyplot as plt
f,i,n=plt.hist(visa_df['prevailing_wage'],bins=40)
print(n)
# Out:
# <BarContainer object of 40 artists>

# %%
import matplotlib.pyplot as plt

plt.hist(visa_df['prevailing_wage'],bins=40)
plt.title("Histogram")
plt.xlabel("Class Interval")
plt.ylabel("Count")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.subplot(3,3,1)
plt.hist(visa_df['prevailing_wage'],bins=40)
plt.title("Histogram")
plt.xlabel("Class Interval")
plt.ylabel("Count")

plt.subplot(3,3,2)
plt.hist(visa_df['prevailing_wage'],bins=40)
plt.title("Histogram")
plt.xlabel("Class Interval")
plt.ylabel("Count")

plt.subplot(3,3,3)
plt.hist(visa_df['prevailing_wage'],bins=40)
plt.title("Histogram")
plt.xlabel("Class Interval")
plt.ylabel("Count")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,3))

plt.subplot(1,3,1)
plt.hist(visa_df['prevailing_wage'],bins=40)
plt.title("Histogram")
plt.xlabel("Class Interval")
plt.ylabel("Count")

plt.subplot(1,3,2)
plt.hist(visa_df['prevailing_wage'],bins=40)
plt.title("Histogram")
plt.xlabel("Class Interval")
plt.ylabel("Count")

plt.subplot(1,3,3)
plt.hist(visa_df['prevailing_wage'],bins=40)
plt.title("Histogram")
plt.xlabel("Class Interval")
plt.ylabel("Count")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,3))
for i in range(len(cols)):
    plt.subplot(1,len(cols),i+1)
    plt.hist(visa_df[cols[i]],bins=40)
    plt.title(f"Histogram of {cols[i]}")
    plt.xlabel("Class interval")
    plt.ylabel("Count")

# %% [markdown]
# **Histogram using seaborn**
#
# - histplot
# - distplot -- going to be removed in future versions
# - displot

# %%
import seaborn as sns

sns.histplot(visa_df['prevailing_wage'])
# Out:
# C:\Users\rachn\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='prevailing_wage', ylabel='Count'>

# %%
import warnings
warnings.filterwarnings("ignore")

sns.distplot(visa_df['prevailing_wage'])
# Out:
# <Axes: xlabel='prevailing_wage', ylabel='Density'>

# %%
import warnings
warnings.filterwarnings("ignore")

sns.displot(visa_df['prevailing_wage'])
